# %%
# ============================================================
# 1-Minute FX Data Downloader – Dukascopy 2015-01-01 → today
# ============================================================

from datetime import datetime
from pathlib import Path
import dukascopy_python as dp
from dukascopy_python.instruments import (
    INSTRUMENT_FX_MAJORS_EUR_USD,
    INSTRUMENT_FX_MAJORS_GBP_USD
)
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from tqdm.auto import tqdm

# ---------- AYARLAR ---------------------------------------------------------
PAIRS = {
    "EURUSD": INSTRUMENT_FX_MAJORS_EUR_USD,
    "GBPUSD": INSTRUMENT_FX_MAJORS_GBP_USD
}

START = datetime(2015, 1, 1)      # 01-01-2015 00:00:00 UTC
END   = datetime.utcnow()         # şimdi
INTERVAL = dp.INTERVAL_MIN_1   # 1-dakika
SIDE     = dp.OFFER_SIDE_BID      # sadece bid fiyatları

OUTPUT_DIR = Path(r"C:/DukascopyData")   #  ←  DİZİNİNİZİ BURAYA YAZIN
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
# ---------------------------------------------------------------------------

def fetch_pair(symbol: str, instrument):
    """Belirtilen pariteyi indirip Parquet'e kaydeder."""
    df = dp.fetch(instrument, INTERVAL, SIDE, START, END)
    out_path = OUTPUT_DIR / f"{symbol}_1min.parquet"
    pq.write_table(
        pa.Table.from_pandas(
            df[["close"]].rename(columns={"close": symbol})
        ),
        out_path,
        compression="snappy"
    )
    print(f"{symbol}: {len(df):,} satır → {out_path}")

# --- İNDİRME döngüsü -------------------------------------------------------
for sym, inst in tqdm(PAIRS.items(), desc="Pairs"):
    fetch_pair(sym, inst)

print("✔︎ Tüm indirmeler tamamlandı.")
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_31756\3926223297.py:24: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   END   = datetime.utcnow()         # şimdi
# Pairs:   0%|          | 0/2 [00:00<?, ?it/s]
# INFO:DUKASCRIPT:current timestamp :2015-01-30T20:09:00
# INFO:DUKASCRIPT:current timestamp :2015-03-02T16:56:00
# INFO:DUKASCRIPT:current timestamp :2015-03-31T12:15:00
# INFO:DUKASCRIPT:current timestamp :2015-04-29T08:34:00
# INFO:DUKASCRIPT:current timestamp :2015-05-28T06:04:00
# INFO:DUKASCRIPT:current timestamp :2015-06-26T02:35:00
# INFO:DUKASCRIPT:current timestamp :2015-07-24T23:06:00
# INFO:DUKASCRIPT:current timestamp :2015-08-24T20:08:00
# INFO:DUKASCRIPT:current timestamp :2015-09-22T16:55:00
# INFO:DUKASCRIPT:current timestamp :2015-10-21T13:36:00
# INFO:DUKASCRIPT:current timestamp :2015-11-19T11:21:00
# ...

# %%
import pandas as pd
eur = pd.read_parquet("C:\DukascopyData\EURUSD_1min.parquet").head()
print(eur.head())
#                         EURUSD
# 2015-01-01 00:00:00  1.20982
# 2015-01-01 00:01:00  1.20973
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\PC\AppData\Local\Temp\ipykernel_31756\2653671719.py:2: SyntaxWarning: invalid escape sequence '\D'
#   eur = pd.read_parquet("C:\DukascopyData\EURUSD_1min.parquet").head()
#                             EURUSD
# timestamp
# 2014-12-31 21:00:00+00:00  1.21005
# 2014-12-31 21:01:00+00:00  1.21005
# 2014-12-31 21:02:00+00:00  1.21005
# 2014-12-31 21:03:00+00:00  1.20996
# 2014-12-31 21:04:00+00:00  1.20996
