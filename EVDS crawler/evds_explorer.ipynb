# %%
from evds import evdsAPI 
import pandas as pd
import numpy as np
pd.options.display.max_rows = 10000

api_key = 'xED0V6IsoE'

evds=evdsAPI(api_key)

evds.get_main_categories()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 10
#       6 api_key = 'xED0V6IsoE'
#       8 evds=evdsAPI(api_key)
# ---> 10 evds.get_main_categories()
#
# AttributeError: 'evdsAPI' object has no attribute 'get_main_categories'
